# %% [markdown]
# teste para aprendizado.

# %%
#importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import util.show_images as show_images

# %%
baseW = pd.read_csv('resultados\will_pill_listed.csv',sep=',')
#1 - 00074-9189-90_PART_1_OF_1_CHAL10_SF_DF1DEFBF.jpg
baseRGB1 = pd.read_csv('resultados\RGBColorSimilarityProcessor - 00074-9189-90_PART_1_OF_1_CHAL10_SF_DF1DEFBF.jpg.csv')
baseHSV1 = pd.read_csv('resultados\HSVColorSimilarityProcessor - 00074-9189-90_PART_1_OF_1_CHAL10_SF_DF1DEFBF.jpg.csv')
baseCIE1 = pd.read_csv('resultados\CIELABColorSimilarityProcessor - 00074-9189-90_PART_1_OF_1_CHAL10_SF_DF1DEFBF.jpg.csv')
#2 - 00085-1322-01_PART_1_OF_1_CHAL10_SF_CF07E78F.jpg
baseRGB2 = pd.read_csv('resultados\RGBColorSimilarityProcessor - 00085-1322-01_PART_1_OF_1_CHAL10_SF_CF07E78F.jpg.csv')
baseHSV2 = pd.read_csv('resultados\HSVColorSimilarityProcessor - 00085-1322-01_PART_1_OF_1_CHAL10_SF_CF07E78F.jpg.csv')
baseCIE2 = pd.read_csv('resultados\CIELABColorSimilarityProcessor - 00085-1322-01_PART_1_OF_1_CHAL10_SF_CF07E78F.jpg.csv')
#3 - 00093-0147-01_PART_1_OF_1_CHAL10_SF_212990BC.jpg
baseRGB3 = pd.read_csv('resultados\RGBColorSimilarityProcessor - 00093-0147-01_PART_1_OF_1_CHAL10_SF_212990BC.jpg.csv')
baseHSV3 = pd.read_csv('resultados\HSVColorSimilarityProcessor - 00093-0147-01_PART_1_OF_1_CHAL10_SF_212990BC.jpg.csv')
baseCIE3 = pd.read_csv('resultados\CIELABColorSimilarityProcessor - 00093-0147-01_PART_1_OF_1_CHAL10_SF_212990BC.jpg.csv')
#4 - 00093-0321-01_PART_1_OF_1_CHAL10_SB_902B486A.jpg
baseRGB4 = pd.read_csv('resultados\RGBColorSimilarityProcessor - 00093-0321-01_PART_1_OF_1_CHAL10_SB_902B486A.jpg.csv')
baseHSV4 = pd.read_csv('resultados\HSVColorSimilarityProcessor - 00093-0321-01_PART_1_OF_1_CHAL10_SB_902B486A.jpg.csv')
baseCIE4 = pd.read_csv('resultados\CIELABColorSimilarityProcessor - 00093-0321-01_PART_1_OF_1_CHAL10_SB_902B486A.jpg.csv')
#5 - 00093-0757-01_PART_1_OF_1_CHAL10_SB_AC2B561A.jpg
baseRGB5 = pd.read_csv('resultados\RGBColorSimilarityProcessor - 00093-0757-01_PART_1_OF_1_CHAL10_SB_AC2B561A.jpg.csv')
baseHSV5 = pd.read_csv('resultados\HSVColorSimilarityProcessor - 00093-0757-01_PART_1_OF_1_CHAL10_SB_AC2B561A.jpg.csv')
baseCIE5 = pd.read_csv('resultados\CIELABColorSimilarityProcessor - 00093-0757-01_PART_1_OF_1_CHAL10_SB_AC2B561A.jpg.csv')

# %%
#gerar unica DB
#comparação 1
baseMIX_RGB1 = baseRGB1.set_index('path').join(baseW.set_index('path'))
del baseMIX_RGB1['Unnamed: 0']
baseMIX_HSV1 = baseHSV1.set_index('path').join(baseW.set_index('path'))
del baseMIX_HSV1['Unnamed: 0']
baseMIX_CIE1 = baseCIE1.set_index('path').join(baseW.set_index('path'))
del baseMIX_CIE1['Unnamed: 0']
#comparação 2
baseMIX_RGB2 = baseRGB2.set_index('path').join(baseW.set_index('path'))
del baseMIX_RGB2['Unnamed: 0']
baseMIX_HSV2 = baseHSV2.set_index('path').join(baseW.set_index('path'))
del baseMIX_HSV2['Unnamed: 0']
baseMIX_CIE2 = baseCIE2.set_index('path').join(baseW.set_index('path'))
del baseMIX_CIE2['Unnamed: 0']
#comparação 3
baseMIX_RGB3 = baseRGB3.set_index('path').join(baseW.set_index('path'))
del baseMIX_RGB3['Unnamed: 0']
baseMIX_HSV3 = baseHSV3.set_index('path').join(baseW.set_index('path'))
del baseMIX_HSV3['Unnamed: 0']
baseMIX_CIE3 = baseCIE3.set_index('path').join(baseW.set_index('path'))
del baseMIX_CIE3['Unnamed: 0']
#comparação 4
baseMIX_RGB4 = baseRGB4.set_index('path').join(baseW.set_index('path'))
del baseMIX_RGB4['Unnamed: 0']
baseMIX_HSV4 = baseHSV4.set_index('path').join(baseW.set_index('path'))
del baseMIX_HSV4['Unnamed: 0']
baseMIX_CIE4 = baseCIE4.set_index('path').join(baseW.set_index('path'))
del baseMIX_CIE4['Unnamed: 0']
#comparação 5
baseMIX_RGB5 = baseRGB5.set_index('path').join(baseW.set_index('path'))
del baseMIX_RGB5['Unnamed: 0']
baseMIX_HSV5 = baseHSV5.set_index('path').join(baseW.set_index('path'))
del baseMIX_HSV5['Unnamed: 0']
baseMIX_CIE5 = baseCIE5.set_index('path').join(baseW.set_index('path'))
del baseMIX_CIE5['Unnamed: 0']

# %%
#"listagem da selecao por RGB"
#baseMIX_RGB1.sort_values(by='distance').ix[290:294]
#baseMIX_RGB2.sort_values(by='distance').ix[290:294]
#baseMIX_RGB3.sort_values(by='distance').ix[290:294]
#baseMIX_RGB4.sort_values(by='distance').ix[290:294]
#baseMIX_RGB5.sort_values(by='distance').ix[290:294]

# %%
#"listagem da selecao por HSV"
baseMIX_HSV1.sort_values(by='distance').ix[0:300]
#baseMIX_HSV2.sort_values(by='distance').ix[290:294]
#baseMIX_HSV3.sort_values(by='distance').ix[290:294]
#baseMIX_HSV4.sort_values(by='distance').ix[290:294]
#baseMIX_HSV5.sort_values(by='distance').ix[290:294]
# Out:
#                                                     distance  color1  color2
# path
# PILL/00093-7247-06_PART_1_OF_1_CHAL10_SF_7329B9...  0.000000    gray     NaN
# PILL/00074-9189-90_PART_1_OF_1_CHAL10_SF_DF1DEF...  0.000000    blue  yellow
# PILL/00093-0576-06_PART_1_OF_1_CHAL10_SF_6026B0...  0.000442    blue     NaN
# PILL/00093-0576-06_PART_1_OF_1_CHAL10_SB_6026B0...  0.000467    blue     NaN
# PILL/00093-5703-01_PART_1_OF_1_CHAL10_SF_7D2DBE...  0.000549  yellow     NaN
# PILL/00093-3127-01_PART_1_OF_1_CHAL10_SF_C12DE0...  0.000767     red    blue
# PILL/00093-5215-01_PART_1_OF_1_CHAL10_SB_562BAB...  0.000830  yellow     NaN
# PILL/00093-3010-84_PART_1_OF_1_CHAL10_SB_F72CFB...  0.000874     red     NaN
# PILL/00093-3127-01_PART_1_OF_1_CHAL10_SB_C12DE0...  0.001054     red    blue
# PILL/00093-5215-01_PART_1_OF_1_CHAL10_SF_562BAB...  0.001131  yellow     NaN
# PILL/00074-9189-90_PART_1_OF_1_CHAL10_SB_DF1DEF...  0.001722    blue  yellow
# ...

# %%
#"listagem da selecao por CIE"
#baseMIX_CIE1.sort_values(by='distance').ix[290:294]
#baseMIX_CIE2.sort_values(by='distance').ix[290:294]
#baseMIX_CIE3.sort_values(by='distance').ix[290:294]
#baseMIX_CIE4.sort_values(by='distance').ix[290:294]
#baseMIX_CIE5.sort_values(by='distance').ix[290:294]

# %% [markdown]
# Imagem 1

# %%
distBase1 = {'RGB' : baseRGB1.distance*1,
     'CIE' : baseCIE1.distance*2,
     'HSV' : baseHSV1.distance*900}

df1 = pd.DataFrame(distBase1)
plt.xlabel("images")
plt.ylabel("distance")


ax1 = plt.axes()
x_axis = ax1.axes.get_yaxis()
x_axis.set_visible(False)

df1.plot(style=['r','g','b'],grid=True,ax=plt.gca(),yticks=[0,0])

plt.show()

#20 primeiras imagens - azul/amarelo
show_images.show(baseRGB1['path'][0:20], title='RGB')
show_images.show(baseCIE1['path'][0:20], title='CIELab')
show_images.show(baseHSV1['path'][0:20], title='HSV')

# %% [markdown]
# Imagem 2

# %%
distBase2 = {'RGB' : baseRGB2.distance*4557,
     'CIE' : baseCIE2.distance*10094,
     'HSV' : baseHSV2.distance*1915800}

df2 = pd.DataFrame(distBase2)
plt.xlabel("images")
plt.ylabel("distance")


ax1 = plt.axes()
x_axis = ax1.axes.get_yaxis()
x_axis.set_visible(False)

df2.plot(style=['r','g','b'],grid=True,ax=plt.gca(),yticks=[0,0])

plt.show()


#20 primeiras imagens - total azul
show_images.show(baseRGB2['path'][0:20], title='RGB')
show_images.show(baseCIE2['path'][0:20], title='CIELab')
show_images.show(baseHSV2['path'][0:20], title='HSV')

# %% [markdown]
# imagem 3

# %%
distBase3 = {'RGB' : baseRGB3.distance*2989,
     'CIE' : baseCIE3.distance*8624,
     'HSV' : baseHSV3.distance*1073600}

df3 = pd.DataFrame(distBase3)
plt.xlabel("images")
plt.ylabel("distance")


ax1 = plt.axes()
x_axis = ax1.axes.get_yaxis()
x_axis.set_visible(False)

df3.plot(style=['r','g','b'],grid=True,ax=plt.gca(),yticks=[0,0])

plt.show()

#20 primeiras imagens - vermelho claro (rosa)
show_images.show(baseRGB3['path'][0:20], title='RGB')
show_images.show(baseCIE3['path'][0:20], title='CIELab')
show_images.show(baseHSV3['path'][0:20], title='HSV')

# %% [markdown]
# imagem 4

# %%
distBase4 = {'RGB' : baseRGB4.distance*2205,
     'CIE' : baseCIE4.distance*5243,
     'HSV' : baseHSV4.distance*963000}

df4 = pd.DataFrame(distBase4)
plt.xlabel("images")
plt.ylabel("distance")


ax1 = plt.axes()
x_axis = ax1.axes.get_yaxis()
x_axis.set_visible(False)

df4.plot(style=['r','g','b'],grid=True,ax=plt.gca(),yticks=[0,0])

plt.show()

#20 primeiras imagens - laranja
show_images.show(baseRGB4['path'][0:20], title='RGB')
show_images.show(baseCIE4['path'][0:20], title='CIELab')
show_images.show(baseHSV4['path'][0:20], title='HSV')

# %% [markdown]
# imagem 5

# %%
distBase5 = {'RGB' : baseRGB5.distance*4851,
     'CIE' : baseCIE5.distance*12544,
     'HSV' : baseHSV5.distance*2534400}

df5 = pd.DataFrame(distBase5)
plt.xlabel("images")
plt.ylabel("distance")


ax1 = plt.axes()
x_axis = ax1.axes.get_yaxis()
x_axis.set_visible(False)

df5.plot(style=['r','g','b'],grid=True,ax=plt.gca(),yticks=[0,0])

plt.show()

#20 primeiras imagens - total verde
show_images.show(baseRGB5['path'][0:20], title='RGB')
show_images.show(baseCIE5['path'][0:20], title='CIELab')
show_images.show(baseHSV5['path'][0:20], title='HSV')
